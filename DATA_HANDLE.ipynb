# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/hoctap/NCKH/EVAGAN
# %cd /content/drive/.shortcut-targets-by-id/1uUf7pXQHZlgN44q_V9w7kkIGdMJgNOXz/NCKH/EVAGAN
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/.shortcut-targets-by-id/1uUf7pXQHZlgN44q_V9w7kkIGdMJgNOXz/NCKH/EVAGAN

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import importlib
from preprocess import *

# %%
#@title Select Option
DATASET = 'CIC-2018' #@param ["CIC-2018", "UNSW_BotIoT", "EdgeIIoT", "InSDN"]
IS_SPLIT = 'True' #@param ["True", "False"]

# %%
workdir = os.getcwd()
data_dir = os.path.join(workdir, "dataset", DATASET)
print(data_dir)
# !ls $data_dir
# %cd $data_dir
# Out:
# /content/drive/.shortcut-targets-by-id/1uUf7pXQHZlgN44q_V9w7kkIGdMJgNOXz/NCKH/EVAGAN/dataset/CIC-2018
# CIC-2018_train_set.csv
# clients
# preprocessed_Friday-02-03-2018_TrafficForML_CICFlowMeter.csv
# results
# /content/drive/.shortcut-targets-by-id/1uUf7pXQHZlgN44q_V9w7kkIGdMJgNOXz/NCKH/EVAGAN/dataset/CIC-2018

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV file
data = pd.read_csv(data_dir + '/' + 'preprocessed_Friday-02-03-2018_TrafficForML_CICFlowMeter.csv')

# Extract the label column

column_names = data.columns.tolist()

# Print the column names
for column in column_names:
    print(column)
    label_column = column
    label_counts = data[label_column].value_counts()

    # Tính tỷ lệ của mỗi nhãn
    label_proportions = data[label_column].value_counts(normalize=True) * 100
    print(label_proportions)

    # In số lượng và tỷ lệ của mỗi nhãn
    print(label_counts.items())
    # for label, count in label_counts.items():
    #     proportion = label_proportions[label]
    #     print(f"Nhãn: {label}, Số lượng: {count}, Tỷ lệ: {proportion:.2f}%")
# Out:
# Unnamed: 0
# 0         0.000254
# 262092    0.000254
# 262354    0.000254
# 262353    0.000254
# 262352    0.000254
#             ...
# 131171    0.000254
# 131170    0.000254
# 131169    0.000254
# 131168    0.000254
# 393520    0.000254
# Name: Unnamed: 0, Length: 393521, dtype: float64
# ...
# Flow Duration
# 1.300000e-07    0.360845
# 1.800000e-07    0.341278
# 2.300000e-07    0.335433
# 3.800000e-07    0.334671
# 3.300000e-07    0.299349
#                   ...
# 3.124000e-05    0.000254
# 6.841630e-03    0.000254
# 6.842720e-03    0.000254
# 6.979810e-03    0.000254
# 3.310542e-02    0.000254
# Name: Flow Duration, Length: 317159, dtype: float64
# ...
# Tot Fwd Pkts
# 0.000162    23.118461
# 0.000046    14.098358
# 0.000185     8.458507
# 0.000000     7.779763
# 0.000209     5.949365
#               ...
# 0.007113     0.000254
# 0.011076     0.000254
# 0.005422     0.000254
# 0.012327     0.000254
# 0.067403     0.000254
# Name: Tot Fwd Pkts, Length: 729, dtype: float64
# ...
# Tot Bwd Pkts
# ...

# %% [markdown]
# **DATA PREPROCESS**

# %%
# preprocess_data_path = ""

# if DATASET == 'UNSW_BotIoT':
#     filename = 'preprocessed_UNSW_2018_IoT_Botnet_Final_10_Best.csv'
#     preprocess_data, preprocess_data_path = prepare_UNSW_IoT(data_dir, filename)
# elif DATASET == 'CIC-2018':
#     filename = 'preprocessed_Friday-02-03-2018_TrafficForML_CICFlowMeter.csv'
#     preprocess_data, preprocess_data_path = prepare_cic_2018(data_dir, filename, CSV_ONE_BOT=0)
# elif DATASET == "EdgeIIoT":
#     filename = 'preprocessed_DNN-EdgeIIoT-dataset.csv'
#     preprocess_data, preprocess_data_path = prepare_EdgeIIoT(data_dir, filename)
# elif DATASET == "InSDN":
#     filename = 'preprocessed_InSDN.csv'
#     preprocess_data, preprocess_data_path = prepare_InSDN(data_dir, filename)
# else:
#     print("Not found dataset")

# preprocess_data['Label'].value_counts()

# %% [markdown]
# **DATA SPLIT**

# %%
# if IS_SPLIT:

#     split_dataset(DATASET, preprocess_data_path)

# %%
# split_dataset(DATASET, "preprocessed_Friday-02-03-2018_TrafficForML_CICFlowMeter.csv")
